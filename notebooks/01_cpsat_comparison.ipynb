# %% [markdown]
# # CP-SAT Comparison
#
# This notebook is kept only as a legacy redirect.
#
# Use [00_quickstart.ipynb](/d:/PythonProjects/PSRP_D3PO/notebooks/00_quickstart.ipynb) for the full workflow:
# - build one shared synthetic instance through `mppsrp_nir`;
# - train `PPO`, `PPO-Lagrangian`, and `D3PO`;
# - compare `untrained vs trained`;
# - compare `trained RL vs CP-SAT`.
